# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df =  pd.read_excel(r'C:\Users\madhuri\Desktop\letsupgrade\Statistics_dinesh\Linear Regression.xlsx',sheet_name = 0)

# %%
df.isna().sum()
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        21613 non-null  int64
#  1   sqft_living  21613 non-null  int64
#  2   bedrooms     21613 non-null  int64
#  3   bathrooms    21613 non-null  float64
#  4   floors       21613 non-null  float64
# dtypes: float64(2), int64(3)
# memory usage: 844.4 KB
# None

# %%
lists = df.columns.to_list()
print(lists)
# Out:
# ['price', 'sqft_living', 'bedrooms', 'bathrooms', 'floors']

# %%
print(lists.remove('price'))
print(lists)
# Out:
# None
# ['sqft_living', 'bedrooms', 'bathrooms', 'floors']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,classification_report
for i in lists:
    x = df[i].values
    y = df['price'].values
    x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.1,random_state = 0)
    '''print(x_train.shape)
    print(y_train.shape)
    print(x_test.shape)
    print(y_test.shape)'''
    x1 = x_train.reshape(-1, 1)
    y1 = y_train.reshape(-1, 1)
    x2 = x_test.reshape(-1, 1)
    y2 = y_test.reshape(-1, 1)
    print(x_train)
    print(x1)
    regressor = LinearRegression()
    regressor.fit(x1,y1)
    y_pred = regressor.predict(x2)
    r2 = r2_score(y_pred,y2)
    print(i)
    print(r2)
    plt.title('Linear Regression(Training set)')
    plt.scatter(x1, y1, color = 'red')
    plt.plot(x1, regressor.predict(x1), color = 'blue')
    plt.title('Linear Regression(Test set)')
    plt.xlabel(i)
    plt.ylabel('Price')
    plt.show()
    plt.scatter(x2, y2, color = 'red')
    plt.plot(x1, regressor.predict(x1), color = 'blue')
    plt.xlabel(i)
    plt.ylabel('Price')
    plt.show()
    print('-------------------------------------------')
# Out:
# [1990  880 1630 ... 2360 2370 2380]
# [[1990]
#  [ 880]
#  [1630]
#  ...
#  [2360]
#  [2370]
#  [2380]]
# sqft_living
# 0.022081078515369224
# -------------------------------------------
# [3 3 3 ... 3 4 4]
# [[3]
#  [3]
#  [3]
#  ...
#  [3]
#  [4]
#  [4]]
# bedrooms
# -8.372902244059688
# -------------------------------------------
# [2.5  1.5  2.25 ... 2.25 2.   2.25]
# [[2.5 ]
#  [1.5 ]
#  [2.25]
#  ...
#  [2.25]
#  [2.  ]
#  [2.25]]
# bathrooms
# -1.281806233239024
# -------------------------------------------
# [1.5 1.  1.  ... 1.  2.  1. ]
# [[1.5]
#  [1. ]
#  [1. ]
#  ...
#  [1. ]
#  [2. ]
#  [1. ]]
# floors
# -11.236409100072771
# -------------------------------------------

# %% [markdown]
# # Multiple linear regression

# %%
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
regressor1 = LinearRegression()
x = df.drop('price',axis = 1)
y = df['price']
print(x)
print(y)
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.1,random_state = 0)
regressor1.fit(x_train,y_train)
y_pred = regressor1.predict(x_test)
r2 = r2_score(y_pred,y_test)
print(r2)
# Out:
#        sqft_living  bedrooms  bathrooms  floors
# 0             1180         3       1.00     1.0
# 1             2570         3       2.25     2.0
# 2              770         2       1.00     1.0
# 3             1960         4       3.00     1.0
# 4             1680         3       2.00     1.0
# ...            ...       ...        ...     ...
# 21608         1530         3       2.50     3.0
# 21609         2310         4       2.50     2.0
# 21610         1020         2       0.75     2.0
# 21611         1600         3       2.50     2.0
# 21612         1020         2       0.75     2.0
#
# [21613 rows x 4 columns]
# 0        221900
# 1        538000
# 2        180000
# 3        604000
# 4        510000
#           ...
# 21608    360000
# 21609    400000
# 21610    402101
# 21611    400000
# 21612    325000
# Name: price, Length: 21613, dtype: int64
# 0.08706323498103152
